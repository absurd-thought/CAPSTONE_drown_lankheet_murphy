# %%
import pyodbc 
import boto3
import pandas as pd
#import psycopg2
import pymysql
from sqlalchemy import create_engine
import os
import sqlite3
import sys
parentDirectory = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
sys.path.insert(0,parentDirectory)
from secretsPaul import secrets
import mysql.connector

import re
import gzip
import shutil
import urllib

# %%
endpoint = EUSVMSQL01.ci826.local
user = secrets.get('DATABASE_USER')
password = secrets.get('DATABASE_PASSWORD')
port=secrets.get('DATABASE_PORT')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 endpoint = EUSVMSQL01.ci826.local
#       2 user = secrets.get('DATABASE_USER')
#       3 password = secrets.get('DATABASE_PASSWORD')
#
# NameError: name 'EUSVMSQL01' is not defined

# %%
connection = create_engine('mssql+pyodbc://EUSVMSQL01.ci826.local/AnalyticsTeamDB?driver=SQL+Server+Native+Client+11.0')
#pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER=EUSVMSQL01.ci826.local;DATABASE=Analyticsteamdb;UID=CI826\Plankheet;PWD=Harrison1841;Trusted_Connection=yes;')

# %%
test = pd.read_csv(os.path.join(parentDirectory,'Data Loading', 'asheville_2022-03-19_listings.csv'))
test
# Out:
#                       id                                      listing_url  \
# 0                 108061              https://www.airbnb.com/rooms/108061
# 1                 155305              https://www.airbnb.com/rooms/155305
# 2                 156805              https://www.airbnb.com/rooms/156805
# 3                 156926              https://www.airbnb.com/rooms/156926
# 4                 160594              https://www.airbnb.com/rooms/160594
# ...                  ...                                              ...
# 2709  582630803698469663  https://www.airbnb.com/rooms/582630803698469663
# 2710  582638114842016072  https://www.airbnb.com/rooms/582638114842016072
# 2711  583433201809490265  https://www.airbnb.com/rooms/583433201809490265
# 2712  583867686874028344  https://www.airbnb.com/rooms/583867686874028344
# 2713  584192080229896466  https://www.airbnb.com/rooms/584192080229896466
#
#            scrape_id last_scraped  \
# 0     20220319010119   2022-03-20
# ...

# %%
test.to_sql('PDLTest',schema='dbo',con=connection, if_exists='replace',index=False)
# Out:
# -1

# %%
## Lets import our requirements
import boto3
import pandas as pd
#import psycopg2
import pymysql
from sqlalchemy import create_engine
import os
import sqlite3
import sys
parentDirectory = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
sys.path.insert(0,parentDirectory)
from secretsPaul import secrets

# %%
# Out:
# Requirement already satisfied: pymysql in c:\users\paull\anaconda32\lib\site-packages (1.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
#connections
endpoint = secrets.get('DATABASE_ENDPOINT')

user = secrets.get('DATABASE_USER')

password = secrets.get('DATABASE_PASSWORD')

port=secrets.get('DATABASE_PORT')

connection = create_engine(f'mysql+pymysql://{user}:{password}@{endpoint}:{port}/Capstone', pool_recycle=3600);

# %%
listing_detail = pd.read_csv(os.path.join(parentDirectory, 'listings.csv'))
listing_detail.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  108061  https://www.airbnb.com/rooms/108061  20221221041414   2022-12-21
# 1  155305  https://www.airbnb.com/rooms/155305  20221221041414   2022-12-21
# 2  156805  https://www.airbnb.com/rooms/156805  20221221041414   2022-12-21
# 3  156926  https://www.airbnb.com/rooms/156926  20221221041414   2022-12-21
# 4  197263  https://www.airbnb.com/rooms/197263  20221221041414   2022-12-21
#
#             source                                               name  \
# 0      city scrape  Walk to stores/parks/downtown. Fenced yard/Pet...
# 1      city scrape                 Cottage! BonPaul + Sharky's Hostel
# 2  previous scrape                  Private Room "Ader" at BPS Hostel
# 3      city scrape             Mixed Dorm "Top Bunk #1" at BPS Hostel
# 4      city scrape                       Tranquil Room & Private Bath
#
#                                          description  \
# 0  Walk to town in ten minutes! Monthly rental $1...
# 1  <b>The space</b><br />Pet friendly private cot...
# 2  <b>The space</b><br />Private Rooms at Bon Pau...
# 3  This is a top bunk in the mixed dorm room<br /...
# 4  This is a comfy, peaceful and clean room with ...
#
#                                neighborhood_overview  \
# 0  I love my neighborhood! Its friendly, easy-goi...
# 1  We are within easy walk of pubs, breweries, mu...
# 2  Easy walk to pubs, cafes, bakery, breweries, l...
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...   320564
# 1  https://a0.muscache.com/pictures/8880711/cf38d...   746673
# 2  https://a0.muscache.com/pictures/23447d55-fa7e...   746673
# 3  https://a0.muscache.com/pictures/98f4e655-c4d6...   746673
# 4  https://a0.muscache.com/pictures/miso/Hosting-...   961396
#
#                                    host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/320564      Lisa  2010-12-16
# 1  https://www.airbnb.com/users/show/746673   BonPaul  2011-06-26
# 2  https://www.airbnb.com/users/show/746673   BonPaul  2011-06-26
# 3  https://www.airbnb.com/users/show/746673   BonPaul  2011-06-26
# 4  https://www.airbnb.com/users/show/961396      Timo  2011-08-12
#
#    host_location                                         host_about  \
# 0  Asheville, NC  I am a long time resident of Asheville and am ...
# 1  Asheville, NC  We operate two traveler's hostels located in H...
# 2  Asheville, NC  We operate two traveler's hostels located in H...
# 3  Asheville, NC  We operate two traveler's hostels located in H...
# 4  Asheville, NC  I'm from Asheville, NC. I'm a yogi, artist and...
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0  within a few hours               100%                  64%
# 1      within an hour                90%                  98%
# 2      within an hour                90%                  98%
# 3      within an hour                90%                  98%
# 4  within a few hours               100%                  91%
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0                 f  https://a0.muscache.com/im/users/320564/profil...
# 1                 t  https://a0.muscache.com/im/pictures/user/4dff7...
# 2                 t  https://a0.muscache.com/im/pictures/user/4dff7...
# 3                 t  https://a0.muscache.com/im/pictures/user/4dff7...
# 4                 t  https://a0.muscache.com/im/users/961396/profil...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/320564/profil...                NaN
# 1  https://a0.muscache.com/im/pictures/user/4dff7...                NaN
# 2  https://a0.muscache.com/im/pictures/user/4dff7...                NaN
# 3  https://a0.muscache.com/im/pictures/user/4dff7...                NaN
# 4  https://a0.muscache.com/im/users/961396/profil...                NaN
#
#    host_listings_count  host_total_listings_count  host_verifications  \
# 0                    2                          3  ['email', 'phone']
# 1                    7                         11  ['email', 'phone']
# 2                    7                         11  ['email', 'phone']
# 3                    7                         11  ['email', 'phone']
# 4                    2                          2  ['email', 'phone']
#
#   host_has_profile_pic host_identity_verified  \
# 0                    t                      t
# 1                    t                      t
# 2                    t                      t
# 3                    t                      t
# 4                    t                      t
#
#                               neighbourhood  neighbourhood_cleansed  \
# 0  Asheville, North Carolina, United States                   28801
# 1  Asheville, North Carolina, United States                   28806
# 2  Asheville, North Carolina, United States                   28806
# 3                                       NaN                   28806
# 4                                       NaN                   28806
#
#    neighbourhood_group_cleansed  latitude  longitude          property_type  \
# 0                           NaN  35.60670  -82.55563     Entire rental unit
# 1                           NaN  35.57864  -82.59578      Entire guesthouse
# 2                           NaN  35.57864  -82.59578   Private room in home
# 3                           NaN  35.57864  -82.59578  Shared room in hostel
# 4                           NaN  35.57808  -82.63689   Private room in home
#
#          room_type  accommodates  bathrooms    bathrooms_text  bedrooms  beds  \
# 0  Entire home/apt             2        NaN            1 bath       1.0   1.0
# 1  Entire home/apt             2        NaN            1 bath       1.0   1.0
# 2     Private room             2        NaN  2.5 shared baths       1.0   1.0
# 3      Shared room             1        NaN  2.5 shared baths       1.0   6.0
# 4     Private room             2        NaN    1 private bath       1.0   1.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["Free street parking", "Cleaning products", "...  $100.00              10
# 1  ["Free street parking", "Oven", "Long term sta...  $100.00               1
# 2  ["Free street parking", "Long term stays allow...   $66.00               1
# 3  ["Air conditioning", "Free parking on premises...   $29.00               1
# 4  ["Free street parking", "Cleaning products", "...   $45.00               2
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0             365                      10                      10
# 1             365                       1                       1
# 2             365                       1                       1
# 3             365                       1                       1
# 4               2                       2                       2
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                    1125                    1125                    10.0
# 1                       7                     365                     1.0
# 2                     365                     365                     1.0
# 3                       1                     365                     1.0
# 4                       2                       2                     2.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                  1125.0               NaN                t               11
# 1                    55.6               NaN                t               19
# 2                   365.0               NaN                t                0
# 3                    69.7               NaN                t               29
# 4                     2.0               NaN                t               23
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               11               11               180            2022-12-21
# 1               49               79               300            2022-12-21
# 2                0                0                 0            2022-12-21
# 3               59               89               313            2022-12-21
# 4               53               83                83            2022-12-21
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                 91                      1                       0
# 1                374                     27                       1
# 2                 67                      0                       0
# 3                319                     23                       0
# 4                 66                     24                       1
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2011-09-21  2022-10-08                  4.51                    4.57
# 1   2011-07-31  2022-12-04                  4.58                    4.71
# 2   2011-09-20  2020-01-01                  4.52                    4.73
# 3   2011-09-01  2022-11-14                  4.72                    4.82
# 4   2012-08-06  2022-11-21                  4.95                    4.97
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.70                   4.85
# 1                       4.41                   4.83
# 2                       4.43                   4.76
# 3                       4.68                   4.85
# 4                       5.00                   4.95
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.80                    4.84                 4.48
# 1                         4.74                    4.93                 4.54
# 2                         4.61                    4.84                 4.46
# 3                         4.79                    4.79                 4.79
# 4                         4.92                    4.82                 4.98
#
#    license instant_bookable  calculated_host_listings_count  \
# 0      NaN                f                               2
# 1      NaN                f                               7
# 2      NaN                t                               7
# 3      NaN                t                               7
# 4      NaN                f                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            2
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             2
# 2                                             2
# 3                                             2
# 4                                             1
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.66
# 1                                            4               2.70
# 2                                            4               0.49
# 3                                            4               2.32
# 4                                            0               0.52

# %%
listing_detail.rename(columns={'id':'listing_id', 'name':'listing_name'})
# Out:
#               listing_id                                      listing_url  \
# 0                 108061              https://www.airbnb.com/rooms/108061
# 1                 155305              https://www.airbnb.com/rooms/155305
# 2                 156805              https://www.airbnb.com/rooms/156805
# 3                 156926              https://www.airbnb.com/rooms/156926
# 4                 197263              https://www.airbnb.com/rooms/197263
# ...                  ...                                              ...
# 3088  781782414720517996  https://www.airbnb.com/rooms/781782414720517996
# 3089  782532660666236690  https://www.airbnb.com/rooms/782532660666236690
# 3090  782566217015314409  https://www.airbnb.com/rooms/782566217015314409
# 3091  783200712500479389  https://www.airbnb.com/rooms/783200712500479389
# 3092  785575328057748301  https://www.airbnb.com/rooms/785575328057748301
#
#            scrape_id last_scraped           source  \
# 0     20221221041414   2022-12-21      city scrape
# 1     20221221041414   2022-12-21      city scrape
# 2     20221221041414   2022-12-21  previous scrape
# 3     20221221041414   2022-12-21      city scrape
# 4     20221221041414   2022-12-21      city scrape
# ...              ...          ...              ...
# 3088  20221221041414   2022-12-21      city scrape
# 3089  20221221041414   2022-12-21      city scrape
# 3090  20221221041414   2022-12-21      city scrape
# 3091  20221221041414   2022-12-30      city scrape
# 3092  20221221041414   2022-12-21      city scrape
#
#                                            listing_name  \
# 0     Walk to stores/parks/downtown. Fenced yard/Pet...
# 1                    Cottage! BonPaul + Sharky's Hostel
# 2                     Private Room "Ader" at BPS Hostel
# 3                Mixed Dorm "Top Bunk #1" at BPS Hostel
# 4                          Tranquil Room & Private Bath
# ...                                                 ...
# 3088                              Studio Cinema on Main
# 3089                                      Tipsy Picasso
# 3090  Modern/Open KingBed Apartment/10mins to Asheville
# 3091  Modern Boho Mountain Getaway - 10 mins to down...
# 3092      Leyland by AvantStay | Cabin Mansion w/ Views
#
#                                             description  \
# 0     Walk to town in ten minutes! Monthly rental $1...
# 1     <b>The space</b><br />Pet friendly private cot...
# 2     <b>The space</b><br />Private Rooms at Bon Pau...
# 3     This is a top bunk in the mixed dorm room<br /...
# 4     This is a comfy, peaceful and clean room with ...
# ...                                                 ...
# 3088  This private studio apartment is located in ou...
# 3089  Find hoppy inspiration at Tipsy Picasso in Ash...
# 3090  Only 10 minutes from Asheville, this light fil...
# 3091  The little things matter. Enjoy a curated expe...
# 3092  Welcome to Leyland! This gorgeous cabin-style ...
#
#                                   neighborhood_overview  \
# 0     I love my neighborhood! Its friendly, easy-goi...
# 1     We are within easy walk of pubs, breweries, mu...
# 2     Easy walk to pubs, cafes, bakery, breweries, l...
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 3088                                                NaN
# 3089  Condo across from New Belgium Brewery in the r...
# 3090                                                NaN
# 3091                                                NaN
# 3092                                                NaN
#
#                                             picture_url    host_id  \
# 0     https://a0.muscache.com/pictures/miso/Hosting-...     320564
# 1     https://a0.muscache.com/pictures/8880711/cf38d...     746673
# 2     https://a0.muscache.com/pictures/23447d55-fa7e...     746673
# 3     https://a0.muscache.com/pictures/98f4e655-c4d6...     746673
# 4     https://a0.muscache.com/pictures/miso/Hosting-...     961396
# ...                                                 ...        ...
# 3088  https://a0.muscache.com/pictures/miso/Hosting-...   41653391
# 3089  https://a0.muscache.com/pictures/miso/Hosting-...   64357179
# 3090  https://a0.muscache.com/pictures/miso/Hosting-...  390463853
# 3091  https://a0.muscache.com/pictures/miso/Hosting-...  241015464
# 3092  https://a0.muscache.com/pictures/prohost-api/H...  480217041
#
#                                          host_url           host_name  \
# 0        https://www.airbnb.com/users/show/320564                Lisa
# 1        https://www.airbnb.com/users/show/746673             BonPaul
# 2        https://www.airbnb.com/users/show/746673             BonPaul
# 3        https://www.airbnb.com/users/show/746673             BonPaul
# 4        https://www.airbnb.com/users/show/961396                Timo
# ...                                           ...                 ...
# 3088   https://www.airbnb.com/users/show/41653391  Michael And Amanda
# 3089   https://www.airbnb.com/users/show/64357179               Kevin
# 3090  https://www.airbnb.com/users/show/390463853               Brian
# 3091  https://www.airbnb.com/users/show/241015464           Mackenzie
# 3092  https://www.airbnb.com/users/show/480217041           AvantStay
#
#       host_since  host_location  \
# 0     2010-12-16  Asheville, NC
# 1     2011-06-26  Asheville, NC
# 2     2011-06-26  Asheville, NC
# 3     2011-06-26  Asheville, NC
# 4     2011-08-12  Asheville, NC
# ...          ...            ...
# 3088  2015-08-16  Asheville, NC
# 3089  2016-03-24  Asheville, NC
# 3090  2021-02-28            NaN
# 3091  2019-02-04      Arden, NC
# 3092  2022-09-19            NaN
#
#                                              host_about  host_response_time  \
# 0     I am a long time resident of Asheville and am ...  within a few hours
# 1     We operate two traveler's hostels located in H...      within an hour
# 2     We operate two traveler's hostels located in H...      within an hour
# 3     We operate two traveler's hostels located in H...      within an hour
# 4     I'm from Asheville, NC. I'm a yogi, artist and...  within a few hours
# ...                                                 ...                 ...
# 3088  In December of 2016 we opened our doors for th...  within a few hours
# 3089                                                NaN      within an hour
# 3090                                                NaN      within an hour
# 3091  Welcome to Asheville! My name is Mackenzie and...      within an hour
# 3092                                                NaN      within an hour
#
#      host_response_rate host_acceptance_rate host_is_superhost  \
# 0                  100%                  64%                 f
# 1                   90%                  98%                 t
# 2                   90%                  98%                 t
# 3                   90%                  98%                 t
# 4                  100%                  91%                 t
# ...                 ...                  ...               ...
# 3088               100%                  96%                 f
# 3089               100%                 100%                 t
# 3090               100%                 100%                 f
# 3091               100%                 100%                 f
# 3092                60%                 100%                 f
#
#                                      host_thumbnail_url  \
# 0     https://a0.muscache.com/im/users/320564/profil...
# 1     https://a0.muscache.com/im/pictures/user/4dff7...
# 2     https://a0.muscache.com/im/pictures/user/4dff7...
# 3     https://a0.muscache.com/im/pictures/user/4dff7...
# 4     https://a0.muscache.com/im/users/961396/profil...
# ...                                                 ...
# 3088  https://a0.muscache.com/im/pictures/user/92d82...
# 3089  https://a0.muscache.com/im/pictures/user/85009...
# 3090  https://a0.muscache.com/im/pictures/user/07937...
# 3091  https://a0.muscache.com/im/pictures/user/a88b9...
# 3092  https://a0.muscache.com/im/pictures/user/80578...
#
#                                        host_picture_url  host_neighbourhood  \
# 0     https://a0.muscache.com/im/users/320564/profil...                 NaN
# 1     https://a0.muscache.com/im/pictures/user/4dff7...                 NaN
# 2     https://a0.muscache.com/im/pictures/user/4dff7...                 NaN
# 3     https://a0.muscache.com/im/pictures/user/4dff7...                 NaN
# 4     https://a0.muscache.com/im/users/961396/profil...                 NaN
# ...                                                 ...                 ...
# 3088  https://a0.muscache.com/im/pictures/user/92d82...              Oakley
# 3089  https://a0.muscache.com/im/pictures/user/85009...                 NaN
# 3090  https://a0.muscache.com/im/pictures/user/07937...                 NaN
# 3091  https://a0.muscache.com/im/pictures/user/a88b9...                 NaN
# 3092  https://a0.muscache.com/im/pictures/user/80578...  Grove Park- Sunset
#
#       host_listings_count  host_total_listings_count  host_verifications  \
# 0                       2                          3  ['email', 'phone']
# 1                       7                         11  ['email', 'phone']
# 2                       7                         11  ['email', 'phone']
# 3                       7                         11  ['email', 'phone']
# 4                       2                          2  ['email', 'phone']
# ...                   ...                        ...                 ...
# 3088                    3                          4  ['email', 'phone']
# 3089                    3                          5           ['phone']
# 3090                   15                         20  ['email', 'phone']
# 3091                    1                          1  ['email', 'phone']
# 3092                    6                          6  ['email', 'phone']
#
#      host_has_profile_pic host_identity_verified  \
# 0                       t                      t
# 1                       t                      t
# 2                       t                      t
# 3                       t                      t
# 4                       t                      t
# ...                   ...                    ...
# 3088                    t                      t
# 3089                    t                      f
# 3090                    t                      t
# 3091                    t                      t
# 3092                    t                      t
#
#                                  neighbourhood  neighbourhood_cleansed  \
# 0     Asheville, North Carolina, United States                   28801
# 1     Asheville, North Carolina, United States                   28806
# 2     Asheville, North Carolina, United States                   28806
# 3                                          NaN                   28806
# 4                                          NaN                   28806
# ...                                        ...                     ...
# 3088                                       NaN                   28803
# 3089  Asheville, North Carolina, United States                   28806
# 3090                                       NaN                   28704
# 3091                                       NaN                   28806
# 3092                                       NaN                   28804
#
#       neighbourhood_group_cleansed   latitude  longitude  \
# 0                              NaN  35.606700 -82.555630
# 1                              NaN  35.578640 -82.595780
# 2                              NaN  35.578640 -82.595780
# 3                              NaN  35.578640 -82.595780
# 4                              NaN  35.578080 -82.636890
# ...                            ...        ...        ...
# 3088                           NaN  35.568150 -82.528210
# 3089                           NaN  35.586004 -82.572200
# 3090                           NaN  35.476180 -82.565920
# 3091                           NaN  35.605320 -82.610260
# 3092                           NaN  35.629074 -82.516178
#
#               property_type        room_type  accommodates  bathrooms  \
# 0        Entire rental unit  Entire home/apt             2        NaN
# 1         Entire guesthouse  Entire home/apt             2        NaN
# 2      Private room in home     Private room             2        NaN
# 3     Shared room in hostel      Shared room             1        NaN
# 4      Private room in home     Private room             2        NaN
# ...                     ...              ...           ...        ...
# 3088            Entire home  Entire home/apt             2        NaN
# 3089           Entire condo  Entire home/apt             2        NaN
# 3090     Entire rental unit  Entire home/apt             2        NaN
# 3091            Entire home  Entire home/apt             8        NaN
# 3092            Entire home  Entire home/apt            16        NaN
#
#         bathrooms_text  bedrooms  beds  \
# 0               1 bath       1.0   1.0
# 1               1 bath       1.0   1.0
# 2     2.5 shared baths       1.0   1.0
# 3     2.5 shared baths       1.0   6.0
# 4       1 private bath       1.0   1.0
# ...                ...       ...   ...
# 3088            1 bath       1.0   1.0
# 3089            1 bath       1.0   1.0
# 3090            1 bath       1.0   1.0
# 3091           2 baths       3.0   4.0
# 3092           4 baths       5.0  11.0
#
#                                               amenities    price  \
# 0     ["Free street parking", "Cleaning products", "...  $100.00
# 1     ["Free street parking", "Oven", "Long term sta...  $100.00
# 2     ["Free street parking", "Long term stays allow...   $66.00
# 3     ["Air conditioning", "Free parking on premises...   $29.00
# 4     ["Free street parking", "Cleaning products", "...   $45.00
# ...                                                 ...      ...
# 3088  ["Free washer \u2013 In building", "Body soap"...  $144.00
# 3089  ["Air conditioning", "TV", "Free parking on pr...   $79.00
# 3090  ["Free street parking", "55\" HDTV with Amazon...   $84.00
# 3091  ["Clothing storage: closet and dresser", "Smar...  $154.00
# 3092  ["Body soap", "Cleaning products", "Dishwasher...  $417.00
#
#       minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0                 10             365                      10
# 1                  1             365                       1
# 2                  1             365                       1
# 3                  1             365                       1
# 4                  2               2                       2
# ...              ...             ...                     ...
# 3088               1             365                       1
# 3089              30             365                      30
# 3090               1             365                       1
# 3091               2            1125                       2
# 3092               1             365                       2
#
#       maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                         10                    1125                    1125
# 1                          1                       7                     365
# 2                          1                     365                     365
# 3                          1                       1                     365
# 4                          2                       2                       2
# ...                      ...                     ...                     ...
# 3088                       1                     365                     365
# 3089                      30                     365                     365
# 3090                       1                     365                     365
# 3091                       2                    1125                    1125
# 3092                       4                     365                     365
#
#       minimum_nights_avg_ntm  maximum_nights_avg_ntm  calendar_updated  \
# 0                       10.0                  1125.0               NaN
# 1                        1.0                    55.6               NaN
# 2                        1.0                   365.0               NaN
# 3                        1.0                    69.7               NaN
# 4                        2.0                     2.0               NaN
# ...                      ...                     ...               ...
# 3088                     1.0                   365.0               NaN
# 3089                    30.0                   365.0               NaN
# 3090                     1.0                   365.0               NaN
# 3091                     2.0                  1125.0               NaN
# 3092                     2.9                   365.0               NaN
#
#      has_availability  availability_30  availability_60  availability_90  \
# 0                   t               11               11               11
# 1                   t               19               49               79
# 2                   t                0                0                0
# 3                   t               29               59               89
# 4                   t               23               53               83
# ...               ...              ...              ...              ...
# 3088                t                8                8               14
# 3089                t               30               60               90
# 3090                t               25               55               85
# 3091                t               18               48               73
# 3092                t               24               50               80
#
#       availability_365 calendar_last_scraped  number_of_reviews  \
# 0                  180            2022-12-21                 91
# 1                  300            2022-12-21                374
# 2                    0            2022-12-21                 67
# 3                  313            2022-12-21                319
# 4                   83            2022-12-21                 66
# ...                ...                   ...                ...
# 3088                14            2022-12-21                  0
# 3089               365            2022-12-21                  0
# 3090               175            2022-12-21                  0
# 3091               348            2022-12-30                  0
# 3092               355            2022-12-21                  0
#
#       number_of_reviews_ltm  number_of_reviews_l30d first_review last_review  \
# 0                         1                       0   2011-09-21  2022-10-08
# 1                        27                       1   2011-07-31  2022-12-04
# 2                         0                       0   2011-09-20  2020-01-01
# 3                        23                       0   2011-09-01  2022-11-14
# 4                        24                       1   2012-08-06  2022-11-21
# ...                     ...                     ...          ...         ...
# 3088                      0                       0          NaN         NaN
# 3089                      0                       0          NaN         NaN
# 3090                      0                       0          NaN         NaN
# 3091                      0                       0          NaN         NaN
# 3092                      0                       0          NaN         NaN
#
#       review_scores_rating  review_scores_accuracy  review_scores_cleanliness  \
# 0                     4.51                    4.57                       4.70
# 1                     4.58                    4.71                       4.41
# 2                     4.52                    4.73                       4.43
# 3                     4.72                    4.82                       4.68
# 4                     4.95                    4.97                       5.00
# ...                    ...                     ...                        ...
# 3088                   NaN                     NaN                        NaN
# 3089                   NaN                     NaN                        NaN
# 3090                   NaN                     NaN                        NaN
# 3091                   NaN                     NaN                        NaN
# 3092                   NaN                     NaN                        NaN
#
#       review_scores_checkin  review_scores_communication  \
# 0                      4.85                         4.80
# 1                      4.83                         4.74
# 2                      4.76                         4.61
# 3                      4.85                         4.79
# 4                      4.95                         4.92
# ...                     ...                          ...
# 3088                    NaN                          NaN
# 3089                    NaN                          NaN
# 3090                    NaN                          NaN
# 3091                    NaN                          NaN
# 3092                    NaN                          NaN
#
#       review_scores_location  review_scores_value  license instant_bookable  \
# 0                       4.84                 4.48      NaN                f
# 1                       4.93                 4.54      NaN                f
# 2                       4.84                 4.46      NaN                t
# 3                       4.79                 4.79      NaN                t
# 4                       4.82                 4.98      NaN                f
# ...                      ...                  ...      ...              ...
# 3088                     NaN                  NaN      NaN                f
# 3089                     NaN                  NaN      NaN                t
# 3090                     NaN                  NaN      NaN                t
# 3091                     NaN                  NaN      NaN                t
# 3092                     NaN                  NaN      NaN                t
#
#       calculated_host_listings_count  \
# 0                                  2
# 1                                  7
# 2                                  7
# 3                                  7
# 4                                  2
# ...                              ...
# 3088                               2
# 3089                               2
# 3090                               2
# 3091                               1
# 3092                               2
#
#       calculated_host_listings_count_entire_homes  \
# 0                                               2
# 1                                               1
# 2                                               1
# 3                                               1
# 4                                               1
# ...                                           ...
# 3088                                            2
# 3089                                            2
# 3090                                            2
# 3091                                            1
# 3092                                            2
#
#       calculated_host_listings_count_private_rooms  \
# 0                                                0
# 1                                                2
# 2                                                2
# 3                                                2
# 4                                                1
# ...                                            ...
# 3088                                             0
# 3089                                             0
# 3090                                             0
# 3091                                             0
# 3092                                             0
#
#       calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                               0               0.66
# 1                                               4               2.70
# 2                                               4               0.49
# 3                                               4               2.32
# 4                                               0               0.52
# ...                                           ...                ...
# 3088                                            0                NaN
# 3089                                            0                NaN
# 3090                                            0                NaN
# 3091                                            0                NaN
# 3092                                            0                NaN
#
# [3093 rows x 75 columns]

# %%
listing_detail['price']=listing_detail['price'].str[1:].str.replace(',','').apply(pd.to_numeric) #changing price column to numeric field
listing_detail['host_acceptance_rate']=listing_detail['host_acceptance_rate'].str[:-1].apply(pd.to_numeric)/100 #change to numeric
listing_detail['host_response_rate']=listing_detail['host_response_rate'].str[:-1].apply(pd.to_numeric)/100

# %%
#converting to datetime
listing_detail[['last_scraped', 'host_since','calendar_last_scraped','first_review','last_review']]=listing_detail[['last_scraped', 'host_since','calendar_last_scraped','first_review','last_review']].apply(pd.to_datetime)

# %%
#converting to 1/0 (better for modeling and summarization)
listing_detail[['host_is_superhost','host_has_profile_pic','host_identity_verified','has_availability','instant_bookable']]=listing_detail[['host_is_superhost','host_has_profile_pic','host_identity_verified','has_availability','instant_bookable']].replace('t',1).replace('f',0)

# %%
listing_detail.to_sql('listing_detail_stage',con=connection, if_exists='replace',index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\Anaconda32\lib\site-packages\sqlalchemy\engine\base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\base.py:476, in _ConnectionRecord.checkout(cls, pool)
#     474 @classmethod
#     475 def checkout(cls, pool):
# --> 476     rec = pool._do_get()
#     477     try:
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\impl.py:146, in QueuePool._do_get(self)
#     145         with util.safe_reraise():
# --> 146             self._dec_overflow()
#     147 else:
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\util\langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\util\compat.py:208, in raise_(***failed resolving arguments***)
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\impl.py:143, in QueuePool._do_get(self)
#     142 try:
# --> 143     return self._create_connection()
#     144 except:
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\base.py:256, in Pool._create_connection(self)
#     254 """Called by subclasses to create a new ConnectionRecord."""
# --> 256 return _ConnectionRecord(self)
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\base.py:371, in _ConnectionRecord.__init__(self, pool, connect)
#     370 if connect:
# --> 371     self.__connect()
#     372 self.finalize_callback = deque()
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\base.py:666, in _ConnectionRecord.__connect(self)
#     665     with util.safe_reraise():
# --> 666         pool.logger.debug("Error on connect(): %s", e)
#     667 else:
#     668     # in SQLAlchemy 1.4 the first_connect event is not used by
#     669     # the engine, so this will usually not be set
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\util\langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\util\compat.py:208, in raise_(***failed resolving arguments***)
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\base.py:661, in _ConnectionRecord.__connect(self)
#     660 self.starttime = time.time()
# --> 661 self.dbapi_connection = connection = pool._invoke_creator(self)
#     662 pool.logger.debug("Created new connection %r", connection)
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\engine\create.py:590, in create_engine.<locals>.connect(connection_record)
#     589             return connection
# --> 590 return dialect.connect(*cargs, **cparams)
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\engine\default.py:597, in DefaultDialect.connect(self, *cargs, **cparams)
#     595 def connect(self, *cargs, **cparams):
#     596     # inherits the docstring from interfaces.Dialect.connect
# --> 597     return self.dbapi.connect(*cargs, **cparams)
#
# File ~\Anaconda32\lib\site-packages\pymysql\connections.py:353, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     352 else:
# --> 353     self.connect()
#
# File ~\Anaconda32\lib\site-packages\pymysql\connections.py:632, in Connection.connect(self, sock)
#     630 self._next_seq_id = 0
# --> 632 self._get_server_information()
#     633 self._request_authentication()
#
# File ~\Anaconda32\lib\site-packages\pymysql\connections.py:1055, in Connection._get_server_information(self)
#    1054 i = 0
# -> 1055 packet = self._read_packet()
#    1056 data = packet.get_all_data()
#
# File ~\Anaconda32\lib\site-packages\pymysql\connections.py:692, in Connection._read_packet(self, packet_type)
#     691 while True:
# --> 692     packet_header = self._read_bytes(4)
#     693     # if DEBUG: dump_packet(packet_header)
#
# File ~\Anaconda32\lib\site-packages\pymysql\connections.py:748, in Connection._read_bytes(self, num_bytes)
#     747     self._force_close()
# --> 748     raise err.OperationalError(
#     749         CR.CR_SERVER_LOST, "Lost connection to MySQL server during query"
#     750     )
#     751 return data
#
# OperationalError: (2013, 'Lost connection to MySQL server during query')
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 listing_detail.to_sql('listing_detail_stage',con=connection, if_exists='replace',index=False)
#
# File ~\Anaconda32\lib\site-packages\pandas\core\generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File ~\Anaconda32\lib\site-packages\pandas\io\sql.py:698, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     693 elif not isinstance(frame, DataFrame):
#     694     raise NotImplementedError(
#     695         "'frame' argument should be either a Series or a DataFrame"
#     696     )
# --> 698 return pandas_sql.to_sql(
#     699     frame,
#     700     name,
#     701     if_exists=if_exists,
#     702     index=index,
#     703     index_label=index_label,
#     704     schema=schema,
#     705     chunksize=chunksize,
#     706     dtype=dtype,
#     707     method=method,
#     708     engine=engine,
#     709     **engine_kwargs,
#     710 )
#
# File ~\Anaconda32\lib\site-packages\pandas\io\sql.py:1732, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1682 """
#    1683 Write records stored in a DataFrame to a SQL database.
#    1684
#    (...)
#    1728     Any additional kwargs are passed to the engine.
#    1729 """
#    1730 sql_engine = get_engine(engine)
# -> 1732 table = self.prep_table(
#    1733     frame=frame,
#    1734     name=name,
#    1735     if_exists=if_exists,
#    1736     index=index,
#    1737     index_label=index_label,
#    1738     schema=schema,
#    1739     dtype=dtype,
#    1740 )
#    1742 total_inserted = sql_engine.insert_records(
#    1743     table=table,
#    1744     con=self.connectable,
#    (...)
#    1751     **engine_kwargs,
#    1752 )
#    1754 self.check_case_sensitive(name=name, schema=schema)
#
# File ~\Anaconda32\lib\site-packages\pandas\io\sql.py:1631, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1619             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1621 table = SQLTable(
#    1622     name,
#    1623     self,
#    (...)
#    1629     dtype=dtype,
#    1630 )
# -> 1631 table.create()
#    1632 return table
#
# File ~\Anaconda32\lib\site-packages\pandas\io\sql.py:832, in SQLTable.create(self)
#     831 def create(self):
# --> 832     if self.exists():
#     833         if self.if_exists == "fail":
#     834             raise ValueError(f"Table '{self.name}' already exists.")
#
# File ~\Anaconda32\lib\site-packages\pandas\io\sql.py:816, in SQLTable.exists(self)
#     815 def exists(self):
# --> 816     return self.pd_sql.has_table(self.name, self.schema)
#
# File ~\Anaconda32\lib\site-packages\pandas\io\sql.py:1765, in SQLDatabase.has_table(self, name, schema)
#    1762 if _gt14():
#    1763     from sqlalchemy import inspect
# -> 1765     insp = inspect(self.connectable)
#    1766     return insp.has_table(name, schema or self.meta.schema)
#    1767 else:
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\inspection.py:64, in inspect(subject, raiseerr)
#      62 if reg is True:
#      63     return subject
# ---> 64 ret = reg(subject)
#      65 if ret is not None:
#      66     break
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\engine\reflection.py:182, in Inspector._engine_insp(bind)
#     180 @inspection._inspects(Engine)
#     181 def _engine_insp(bind):
# --> 182     return Inspector._construct(Inspector._init_engine, bind)
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\engine\reflection.py:117, in Inspector._construct(cls, init, bind)
#     114     cls = bind.dialect.inspector
#     116 self = cls.__new__(cls)
# --> 117 init(self, bind)
#     118 return self
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\engine\reflection.py:128, in Inspector._init_engine(self, engine)
#     126 def _init_engine(self, engine):
#     127     self.bind = self.engine = engine
# --> 128     engine.connect().close()
#     129     self._op_context_requires_connect = True
#     130     self.dialect = self.engine.dialect
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\engine\base.py:3234, in Engine.connect(self, close_with_result)
#    3219 def connect(self, close_with_result=False):
#    3220     """Return a new :class:`_engine.Connection` object.
#    3221
#    3222     The :class:`_engine.Connection` object is a facade that uses a DBAPI
#    (...)
#    3231
#    3232     """
# -> 3234     return self._connection_cls(self, close_with_result=close_with_result)
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\engine\base.py:96, in Connection.__init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      91     self._has_events = _branch_from._has_events
#      92 else:
#      93     self._dbapi_connection = (
#      94         connection
#      95         if connection is not None
# ---> 96         else engine.raw_connection()
#      97     )
#      99     self._transaction = self._nested_transaction = None
#     100     self.__savepoint_seq = 0
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\engine\base.py:3313, in Engine.raw_connection(self, _connection)
#    3291 def raw_connection(self, _connection=None):
#    3292     """Return a "raw" DBAPI connection from the connection pool.
#    3293
#    3294     The returned object is a proxied version of the DBAPI
#    (...)
#    3311
#    3312     """
# -> 3313     return self._wrap_pool_connect(self.pool.connect, _connection)
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\engine\base.py:3283, in Engine._wrap_pool_connect(self, fn, connection)
#    3281 except dialect.dbapi.Error as e:
#    3282     if connection is None:
# -> 3283         Connection._handle_dbapi_exception_noconnection(
#    3284             e, dialect, self
#    3285         )
#    3286     else:
#    3287         util.raise_(
#    3288             sys.exc_info()[1], with_traceback=sys.exc_info()[2]
#    3289         )
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\engine\base.py:2117, in Connection._handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2115     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2116 elif should_wrap:
# -> 2117     util.raise_(
#    2118         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2119     )
#    2120 else:
#    2121     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\util\compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\engine\base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3278 dialect = self.dialect
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#    3282     if connection is None:
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\base.py:310, in Pool.connect(self)
#     302 def connect(self):
#     303     """Return a DBAPI connection from the pool.
#     304
#     305     The connection is instrumented such that when its
#    (...)
#     308
#     309     """
# --> 310     return _ConnectionFairy._checkout(self)
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     865 @classmethod
#     866 def _checkout(cls, pool, threadconns=None, fairy=None):
#     867     if not fairy:
# --> 868         fairy = _ConnectionRecord.checkout(pool)
#     870         fairy._pool = pool
#     871         fairy._counter = 0
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\base.py:476, in _ConnectionRecord.checkout(cls, pool)
#     474 @classmethod
#     475 def checkout(cls, pool):
# --> 476     rec = pool._do_get()
#     477     try:
#     478         dbapi_connection = rec.get_connection()
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\impl.py:146, in QueuePool._do_get(self)
#     144     except:
#     145         with util.safe_reraise():
# --> 146             self._dec_overflow()
#     147 else:
#     148     return self._do_get()
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\util\langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\util\compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\impl.py:143, in QueuePool._do_get(self)
#     141 if self._inc_overflow():
#     142     try:
# --> 143         return self._create_connection()
#     144     except:
#     145         with util.safe_reraise():
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\base.py:256, in Pool._create_connection(self)
#     253 def _create_connection(self):
#     254     """Called by subclasses to create a new ConnectionRecord."""
# --> 256     return _ConnectionRecord(self)
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\base.py:371, in _ConnectionRecord.__init__(self, pool, connect)
#     369 self.__pool = pool
#     370 if connect:
# --> 371     self.__connect()
#     372 self.finalize_callback = deque()
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\base.py:666, in _ConnectionRecord.__connect(self)
#     664 except Exception as e:
#     665     with util.safe_reraise():
# --> 666         pool.logger.debug("Error on connect(): %s", e)
#     667 else:
#     668     # in SQLAlchemy 1.4 the first_connect event is not used by
#     669     # the engine, so this will usually not be set
#     670     if pool.dispatch.first_connect:
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\util\langhelpers.py:70, in safe_reraise.__exit__(self, type_, value, traceback)
#      68     self._exc_info = None  # remove potential circular references
#      69     if not self.warn_only:
# ---> 70         compat.raise_(
#      71             exc_value,
#      72             with_traceback=exc_tb,
#      73         )
#      74 else:
#      75     if not compat.py3k and self._exc_info and self._exc_info[1]:
#      76         # emulate Py3K's behavior of telling us when an exception
#      77         # occurs in an exception handler.
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\util\compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\pool\base.py:661, in _ConnectionRecord.__connect(self)
#     659 try:
#     660     self.starttime = time.time()
# --> 661     self.dbapi_connection = connection = pool._invoke_creator(self)
#     662     pool.logger.debug("Created new connection %r", connection)
#     663     self.fresh = True
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\engine\create.py:590, in create_engine.<locals>.connect(connection_record)
#     588         if connection is not None:
#     589             return connection
# --> 590 return dialect.connect(*cargs, **cparams)
#
# File ~\Anaconda32\lib\site-packages\sqlalchemy\engine\default.py:597, in DefaultDialect.connect(self, *cargs, **cparams)
#     595 def connect(self, *cargs, **cparams):
#     596     # inherits the docstring from interfaces.Dialect.connect
# --> 597     return self.dbapi.connect(*cargs, **cparams)
#
# File ~\Anaconda32\lib\site-packages\pymysql\connections.py:353, in Connection.__init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351     self._sock = None
#     352 else:
# --> 353     self.connect()
#
# File ~\Anaconda32\lib\site-packages\pymysql\connections.py:632, in Connection.connect(self, sock)
#     629 self._rfile = sock.makefile("rb")
#     630 self._next_seq_id = 0
# --> 632 self._get_server_information()
#     633 self._request_authentication()
#     635 if self.sql_mode is not None:
#
# File ~\Anaconda32\lib\site-packages\pymysql\connections.py:1055, in Connection._get_server_information(self)
#    1053 def _get_server_information(self):
#    1054     i = 0
# -> 1055     packet = self._read_packet()
#    1056     data = packet.get_all_data()
#    1058     self.protocol_version = data[i]
#
# File ~\Anaconda32\lib\site-packages\pymysql\connections.py:692, in Connection._read_packet(self, packet_type)
#     690 buff = bytearray()
#     691 while True:
# --> 692     packet_header = self._read_bytes(4)
#     693     # if DEBUG: dump_packet(packet_header)
#     695     btrl, btrh, packet_number = struct.unpack("<HBB", packet_header)
#
# File ~\Anaconda32\lib\site-packages\pymysql\connections.py:748, in Connection._read_bytes(self, num_bytes)
#     746 if len(data) < num_bytes:
#     747     self._force_close()
# --> 748     raise err.OperationalError(
#     749         CR.CR_SERVER_LOST, "Lost connection to MySQL server during query"
#     750     )
#     751 return data
#
# OperationalError: (pymysql.err.OperationalError) (2013, 'Lost connection to MySQL server during query')
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %% [markdown]
# ### Calendar

# %%
calendar = pd.read_csv(os.path.join(parentDirectory, 'calendar.csv'))
calendar.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0      108061  2022-12-21         t  $100.00        $100.00            10.0
# 1      108061  2022-12-22         t  $100.00        $100.00            10.0
# 2      108061  2022-12-23         t  $100.00        $100.00            10.0
# 3      108061  2022-12-24         t  $100.00        $100.00            10.0
# 4      108061  2022-12-25         t  $100.00        $100.00            10.0
#
#    maximum_nights
# 0          1125.0
# 1          1125.0
# 2          1125.0
# 3          1125.0
# 4          1125.0

# %%
calendar['price']=calendar['price'].str[1:].str.replace(',','').apply(pd.to_numeric) #changing price column to numeric field
calendar['adjusted_price']=calendar['adjusted_price'].str[1:].str.replace(',','').apply(pd.to_numeric) #changing price column to numeric field
calendar['date']=calendar['date'].apply(pd.to_datetime)
calendar['available']=calendar['available'].replace('t',1).replace('f',0)

# %%
calendar.rename(columns={'date':'calendar_date'})
# Out:
#          listing_id calendar_date  available  price  adjusted_price  \
# 0            108061    2022-12-21          1  100.0           100.0
# 1            108061    2022-12-22          1  100.0           100.0
# 2            108061    2022-12-23          1  100.0           100.0
# 3            108061    2022-12-24          1  100.0           100.0
# 4            108061    2022-12-25          1  100.0           100.0
# ...             ...           ...        ...    ...             ...
# 1128940     2607570    2023-12-16          1   83.0            83.0
# 1128941     2607570    2023-12-17          1   83.0            83.0
# 1128942     2607570    2023-12-18          1   83.0            83.0
# 1128943     2607570    2023-12-19          1   83.0            83.0
# 1128944     2607570    2023-12-20          1   83.0            83.0
#
#          minimum_nights  maximum_nights
# 0                  10.0          1125.0
# 1                  10.0          1125.0
# 2                  10.0          1125.0
# 3                  10.0          1125.0
# 4                  10.0          1125.0
# ...                 ...             ...
# 1128940            30.0          1125.0
# 1128941            30.0          1125.0
# 1128942            30.0          1125.0
# 1128943            30.0          1125.0
# 1128944            30.0          1125.0
#
# [1128945 rows x 7 columns]

# %%
calendar.to_sql('calendar_stage',con=connection, if_exists='replace',index=False)
# Out:
# 1128945

# %% [markdown]
# ### Reviews

# %%
reviews = pd.read_csv(os.path.join(parentDirectory, 'reviews.csv'))
reviews.head()
# Out:
#    listing_id       id        date  reviewer_id  reviewer_name  \
# 0      108061   553741  2011-09-21       822907  Pedro & Katie
# 1      108061   683278  2011-11-01       236064            Tim
# 2      108061   714889  2011-11-13      1382707          Shane
# 3      108061  1766157  2012-07-21       416731         Brenda
# 4      108061  2033065  2012-08-19      1858880        Lindsey
#
#                                             comments
# 0  Lisa is superb hostess, she will treat you lik...
# 1  This was a lovely little place walking distanc...
# 2  Lisa was very nice to work with.  However, we ...
# 3  I feel very lucky to have found this beautiful...
# 4  Great roomy little apartment, beautiful privat...

# %%
reviews['date']=reviews['date'].apply(pd.to_datetime)

# %%
reviews.rename(columns={'date':'review_date'})
# Out:
#                 listing_id                  id review_date  reviewer_id  \
# 0                   108061              553741  2011-09-21       822907
# 1                   108061              683278  2011-11-01       236064
# 2                   108061              714889  2011-11-13      1382707
# 3                   108061             1766157  2012-07-21       416731
# 4                   108061             2033065  2012-08-19      1858880
# ...                    ...                 ...         ...          ...
# 294512  712360798735711174  784780918253973265  2022-12-18    101520424
# 294513  712997789140305161  744202292090388128  2022-10-23     80245934
# 294514  712997789140305161  760906275979257073  2022-11-15    461947486
# 294515  713624151554100780  763787747692229926  2022-11-19    456924948
# 294516  714377701528965422  753652718742197936  2022-11-05    160617719
#
#         reviewer_name                                           comments
# 0       Pedro & Katie  Lisa is superb hostess, she will treat you lik...
# 1                 Tim  This was a lovely little place walking distanc...
# 2               Shane  Lisa was very nice to work with.  However, we ...
# 3              Brenda  I feel very lucky to have found this beautiful...
# 4             Lindsey  Great roomy little apartment, beautiful privat...
# ...               ...                                                ...
# 294512       Michelle  Loved this small community and cabin! Great lo...
# 294513         Ellyse  We had a great stay! The house was clean and s...
# 294514         Vickie                 The place was very nice and clean.
# 294515           Kyle  Beautiful space in a good location, close to a...
# 294516          Quinn  Beautiful place, beautiful view. The pictures ...
#
# [294517 rows x 6 columns]

# %%
reviews.to_sql('reviews_stage',con=connection, if_exists='replace',index=False)
# Out:
# 294517

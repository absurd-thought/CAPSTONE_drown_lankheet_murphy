# %%
## Lets import our requirements
import boto3
import pandas as pd
#import psycopg2
import pymysql
from sqlalchemy import create_engine
import os
import sqlite3
import sys
parentDirectory = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
sys.path.insert(0,parentDirectory)
from secretsPaul import secrets
import mysql.connector

# %%
# Out:
# Collecting mysql.connector
#   Downloading mysql-connector-2.2.9.tar.gz (11.9 MB)
#      ---------------------------------------- 11.9/11.9 MB 6.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: mysql.connector
#   Building wheel for mysql.connector (setup.py): started
#   Building wheel for mysql.connector (setup.py): finished with status 'done'
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp39-cp39-win_amd64.whl size=247946 sha256=cfadce99788a5b7d28ac1a79f9c285e83b95b88195e0922ba048392364f5fe31
#   Stored in directory: c:\users\paull\appdata\local\pip\cache\wheels\7b\14\39\5aad423666e827dfe9a1fbcd111ac17171e7c9865d570780ce
# Successfully built mysql.connector
# Installing collected packages: mysql.connector
# Successfully installed mysql.connector-2.2.9
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
#connections
endpoint = secrets.get('DATABASE_ENDPOINT')

user = secrets.get('DATABASE_USER')

password = secrets.get('DATABASE_PASSWORD')

port=secrets.get('DATABASE_PORT')

connection = create_engine(f'mysql+pymysql://{user}:{password}@{endpoint}:{port}/Capstone', pool_recycle=3600);

connect=mysql.connector.connect(host=endpoint, database='Capstone', user=user, password=password)
cursor = connect.cursor()

# %%
listing_detail = pd.read_csv(os.path.join(parentDirectory, 'listings.csv'))
listing_detail.head()
# Out:
#        id                          listing_url       scrape_id last_scraped  \
# 0  108061  https://www.airbnb.com/rooms/108061  20221221041414   2022-12-21
# 1  155305  https://www.airbnb.com/rooms/155305  20221221041414   2022-12-21
# 2  156805  https://www.airbnb.com/rooms/156805  20221221041414   2022-12-21
# 3  156926  https://www.airbnb.com/rooms/156926  20221221041414   2022-12-21
# 4  197263  https://www.airbnb.com/rooms/197263  20221221041414   2022-12-21
#
#             source                                               name  \
# 0      city scrape  Walk to stores/parks/downtown. Fenced yard/Pet...
# 1      city scrape                 Cottage! BonPaul + Sharky's Hostel
# 2  previous scrape                  Private Room "Ader" at BPS Hostel
# 3      city scrape             Mixed Dorm "Top Bunk #1" at BPS Hostel
# 4      city scrape                       Tranquil Room & Private Bath
#
#                                          description  \
# 0  Walk to town in ten minutes! Monthly rental $1...
# 1  <b>The space</b><br />Pet friendly private cot...
# 2  <b>The space</b><br />Private Rooms at Bon Pau...
# 3  This is a top bunk in the mixed dorm room<br /...
# 4  This is a comfy, peaceful and clean room with ...
#
#                                neighborhood_overview  \
# 0  I love my neighborhood! Its friendly, easy-goi...
# 1  We are within easy walk of pubs, breweries, mu...
# 2  Easy walk to pubs, cafes, bakery, breweries, l...
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...   320564
# 1  https://a0.muscache.com/pictures/8880711/cf38d...   746673
# 2  https://a0.muscache.com/pictures/23447d55-fa7e...   746673
# 3  https://a0.muscache.com/pictures/98f4e655-c4d6...   746673
# 4  https://a0.muscache.com/pictures/miso/Hosting-...   961396
#
#                                    host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/320564      Lisa  2010-12-16
# 1  https://www.airbnb.com/users/show/746673   BonPaul  2011-06-26
# 2  https://www.airbnb.com/users/show/746673   BonPaul  2011-06-26
# 3  https://www.airbnb.com/users/show/746673   BonPaul  2011-06-26
# 4  https://www.airbnb.com/users/show/961396      Timo  2011-08-12
#
#    host_location                                         host_about  \
# 0  Asheville, NC  I am a long time resident of Asheville and am ...
# 1  Asheville, NC  We operate two traveler's hostels located in H...
# 2  Asheville, NC  We operate two traveler's hostels located in H...
# 3  Asheville, NC  We operate two traveler's hostels located in H...
# 4  Asheville, NC  I'm from Asheville, NC. I'm a yogi, artist and...
#
#    host_response_time host_response_rate host_acceptance_rate  \
# 0  within a few hours               100%                  64%
# 1      within an hour                90%                  98%
# 2      within an hour                90%                  98%
# 3      within an hour                90%                  98%
# 4  within a few hours               100%                  91%
#
#   host_is_superhost                                 host_thumbnail_url  \
# 0                 f  https://a0.muscache.com/im/users/320564/profil...
# 1                 t  https://a0.muscache.com/im/pictures/user/4dff7...
# 2                 t  https://a0.muscache.com/im/pictures/user/4dff7...
# 3                 t  https://a0.muscache.com/im/pictures/user/4dff7...
# 4                 t  https://a0.muscache.com/im/users/961396/profil...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/320564/profil...                NaN
# 1  https://a0.muscache.com/im/pictures/user/4dff7...                NaN
# 2  https://a0.muscache.com/im/pictures/user/4dff7...                NaN
# 3  https://a0.muscache.com/im/pictures/user/4dff7...                NaN
# 4  https://a0.muscache.com/im/users/961396/profil...                NaN
#
#    host_listings_count  host_total_listings_count  host_verifications  \
# 0                    2                          3  ['email', 'phone']
# 1                    7                         11  ['email', 'phone']
# 2                    7                         11  ['email', 'phone']
# 3                    7                         11  ['email', 'phone']
# 4                    2                          2  ['email', 'phone']
#
#   host_has_profile_pic host_identity_verified  \
# 0                    t                      t
# 1                    t                      t
# 2                    t                      t
# 3                    t                      t
# 4                    t                      t
#
#                               neighbourhood  neighbourhood_cleansed  \
# 0  Asheville, North Carolina, United States                   28801
# 1  Asheville, North Carolina, United States                   28806
# 2  Asheville, North Carolina, United States                   28806
# 3                                       NaN                   28806
# 4                                       NaN                   28806
#
#    neighbourhood_group_cleansed  latitude  longitude          property_type  \
# 0                           NaN  35.60670  -82.55563     Entire rental unit
# 1                           NaN  35.57864  -82.59578      Entire guesthouse
# 2                           NaN  35.57864  -82.59578   Private room in home
# 3                           NaN  35.57864  -82.59578  Shared room in hostel
# 4                           NaN  35.57808  -82.63689   Private room in home
#
#          room_type  accommodates  bathrooms    bathrooms_text  bedrooms  beds  \
# 0  Entire home/apt             2        NaN            1 bath       1.0   1.0
# 1  Entire home/apt             2        NaN            1 bath       1.0   1.0
# 2     Private room             2        NaN  2.5 shared baths       1.0   1.0
# 3      Shared room             1        NaN  2.5 shared baths       1.0   6.0
# 4     Private room             2        NaN    1 private bath       1.0   1.0
#
#                                            amenities    price  minimum_nights  \
# 0  ["Free street parking", "Cleaning products", "...  $100.00              10
# 1  ["Free street parking", "Oven", "Long term sta...  $100.00               1
# 2  ["Free street parking", "Long term stays allow...   $66.00               1
# 3  ["Air conditioning", "Free parking on premises...   $29.00               1
# 4  ["Free street parking", "Cleaning products", "...   $45.00               2
#
#    maximum_nights  minimum_minimum_nights  maximum_minimum_nights  \
# 0             365                      10                      10
# 1             365                       1                       1
# 2             365                       1                       1
# 3             365                       1                       1
# 4               2                       2                       2
#
#    minimum_maximum_nights  maximum_maximum_nights  minimum_nights_avg_ntm  \
# 0                    1125                    1125                    10.0
# 1                       7                     365                     1.0
# 2                     365                     365                     1.0
# 3                       1                     365                     1.0
# 4                       2                       2                     2.0
#
#    maximum_nights_avg_ntm  calendar_updated has_availability  availability_30  \
# 0                  1125.0               NaN                t               11
# 1                    55.6               NaN                t               19
# 2                   365.0               NaN                t                0
# 3                    69.7               NaN                t               29
# 4                     2.0               NaN                t               23
#
#    availability_60  availability_90  availability_365 calendar_last_scraped  \
# 0               11               11               180            2022-12-21
# 1               49               79               300            2022-12-21
# 2                0                0                 0            2022-12-21
# 3               59               89               313            2022-12-21
# 4               53               83                83            2022-12-21
#
#    number_of_reviews  number_of_reviews_ltm  number_of_reviews_l30d  \
# 0                 91                      1                       0
# 1                374                     27                       1
# 2                 67                      0                       0
# 3                319                     23                       0
# 4                 66                     24                       1
#
#   first_review last_review  review_scores_rating  review_scores_accuracy  \
# 0   2011-09-21  2022-10-08                  4.51                    4.57
# 1   2011-07-31  2022-12-04                  4.58                    4.71
# 2   2011-09-20  2020-01-01                  4.52                    4.73
# 3   2011-09-01  2022-11-14                  4.72                    4.82
# 4   2012-08-06  2022-11-21                  4.95                    4.97
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.70                   4.85
# 1                       4.41                   4.83
# 2                       4.43                   4.76
# 3                       4.68                   4.85
# 4                       5.00                   4.95
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.80                    4.84                 4.48
# 1                         4.74                    4.93                 4.54
# 2                         4.61                    4.84                 4.46
# 3                         4.79                    4.79                 4.79
# 4                         4.92                    4.82                 4.98
#
#    license instant_bookable  calculated_host_listings_count  \
# 0      NaN                f                               2
# 1      NaN                f                               7
# 2      NaN                t                               7
# 3      NaN                t                               7
# 4      NaN                f                               2
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            2
# 1                                            1
# 2                                            1
# 3                                            1
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             2
# 2                                             2
# 3                                             2
# 4                                             1
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.66
# 1                                            4               2.70
# 2                                            4               0.49
# 3                                            4               2.32
# 4                                            0               0.52

# %%
listing_detail.rename(columns={'id':'listing_id', 'name':'listing_name'}, inplace=True)

# %%
listing_detail['price']=listing_detail['price'].str[1:].str.replace(',','').apply(pd.to_numeric) #changing price column to numeric field
listing_detail['host_acceptance_rate']=listing_detail['host_acceptance_rate'].str[:-1].apply(pd.to_numeric)/100 #change to numeric
listing_detail['host_response_rate']=listing_detail['host_response_rate'].str[:-1].apply(pd.to_numeric)/100

# %%
#converting to datetime
listing_detail[['last_scraped', 'host_since','calendar_last_scraped','first_review','last_review']]=listing_detail[['last_scraped', 'host_since','calendar_last_scraped','first_review','last_review']].apply(pd.to_datetime)

# %%
#converting to 1/0 (better for modeling and summarization)
listing_detail[['host_is_superhost','host_has_profile_pic','host_identity_verified','has_availability','instant_bookable']]=listing_detail[['host_is_superhost','host_has_profile_pic','host_identity_verified','has_availability','instant_bookable']].replace('t',1).replace('f',0)

# %%
listing_detail.to_sql('listing_detail_stage',con=connection, if_exists='replace',index=False)
# Out:
# 3093

# %% [markdown]
# ### Calendar

# %%
calendar = pd.read_csv(os.path.join(parentDirectory, 'calendar.csv'))
calendar.head()
# Out:
#    listing_id        date available    price adjusted_price  minimum_nights  \
# 0      108061  2022-12-21         t  $100.00        $100.00            10.0
# 1      108061  2022-12-22         t  $100.00        $100.00            10.0
# 2      108061  2022-12-23         t  $100.00        $100.00            10.0
# 3      108061  2022-12-24         t  $100.00        $100.00            10.0
# 4      108061  2022-12-25         t  $100.00        $100.00            10.0
#
#    maximum_nights
# 0          1125.0
# 1          1125.0
# 2          1125.0
# 3          1125.0
# 4          1125.0

# %%
calendar['price']=pd.to_numeric(calendar['price'].str[1:].str.replace(',','')) #changing price column to numeric field
calendar['adjusted_price']=pd.to_numeric(calendar['adjusted_price'].str[1:].str.replace(',','')) #changing price column to numeric field
calendar['date']=pd.to_datetime(calendar['date'],infer_datetime_format=True)
calendar['available']=calendar['available'].replace('t',1).replace('f',0)

# %%
calendar.rename(columns={'date':'calendar_date'}, inplace=True)

# %%
from sqlalchemy import event
@event.listens_for(connection, "before_cursor_execute")
def receive_before_cursor_execute(
       conn, cursor, statement, params, context, executemany
        ):
            if executemany:
                cursor.fast_executemany = True

# %%
calendar.to_sql('calendar_stage',con=connection, if_exists='replace',index=False, method='multi')

# %%
calendar.to_csv('data.csv')

# %%
cursor.execute("select database();")
record=cursor.fetchone()
print(record)
# Out:
# ('Capstone',)

# %%
sql_query = "LOAD DATA LOCAL INFILE 'data.csv' REPLACE INTO TABLE calendar_stage FIELDS TERMINATED BY ',';"
# %timeit -r 1 -n 1 cursor.execute(sql_query)
# Out:
# 46.5 s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# ### Reviews

# %%
reviews = pd.read_csv(os.path.join(parentDirectory, 'reviews.csv'))
reviews.head()
# Out:
#    listing_id       id        date  reviewer_id  reviewer_name  \
# 0      108061   553741  2011-09-21       822907  Pedro & Katie
# 1      108061   683278  2011-11-01       236064            Tim
# 2      108061   714889  2011-11-13      1382707          Shane
# 3      108061  1766157  2012-07-21       416731         Brenda
# 4      108061  2033065  2012-08-19      1858880        Lindsey
#
#                                             comments
# 0  Lisa is superb hostess, she will treat you lik...
# 1  This was a lovely little place walking distanc...
# 2  Lisa was very nice to work with.  However, we ...
# 3  I feel very lucky to have found this beautiful...
# 4  Great roomy little apartment, beautiful privat...

# %%
reviews['date']=reviews['date'].apply(pd.to_datetime)

# %%
reviews.rename(columns={'date':'review_date'}, inplace=True)

# %%
reviews.to_sql('reviews_stage',con=connection, if_exists='replace',index=False)
# Out:
# 294517
